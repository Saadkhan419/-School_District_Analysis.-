# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to change the path if needed.)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read the School Data and Student Data and store into a Pandas DataFrame
school_data_df = pd.read_csv(school_data_to_load)
student_data_df = pd.read_csv(student_data_to_load)

# Cleaning Student Names and Replacing Substrings in a Python String
# Add each prefix and suffix to remove to a list.
prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]

# Iterate through the words in the "prefixes_suffixes" list and replace them with an empty space, "".
for word in prefixes_suffixes:
    student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")

# Check names.
student_data_df.head(10)
# Out:
# <ipython-input-5-e456d7f40152>:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")
#    Student ID     student_name gender grade        school_name  reading_score  \
# 0           0     Paul Bradley      M   9th  Huang High School             66
# 1           1     Victor Smith      M  12th  Huang High School             94
# 2           2  Kevin Rodriguez      M  12th  Huang High School             90
# 3           3    Richard Scott      M  12th  Huang High School             67
# 4           4       Bonnie Ray      F   9th  Huang High School             97
# 5           5    Bryan Miranda      M   9th  Huang High School             94
# 6           6    Sheena Carter      F  11th  Huang High School             82
# 7           7     Nicole Baker      F  12th  Huang High School             96
# 8           8     Michael Roth      M  10th  Huang High School             95
# 9           9   Matthew Greene      M  10th  Huang High School             96
#
#    math_score
# 0          79
# 1          61
# 2          60
# 3          58
# 4          84
# 5          94
# 6          80
# 7          69
# 8          87
# 9          84

# %% [markdown]
# ## Deliverable 1: Replace the reading and math scores.
#
# ### Replace the 9th grade reading and math scores at Thomas High School with NaN.

# %%
# Install numpy using conda install numpy or pip install numpy. 
# Step 1. Import numpy as np.
import numpy as np

# %%
# Step 2. Use the loc method on the student_data_df to select all the reading scores from the 9th grade at Thomas High School and replace them with NaN.
student_data_df.loc[(student_data_df['school_name'] == 'Thomas High School') & (student_data_df['grade'] == '9th'), ['reading_score']] = np.nan

# %%
#  Step 3. Refactor the code in Step 2 to replace the math scores with NaN.
student_data_df.loc[(student_data_df['school_name'] == 'Thomas High School') & (student_data_df['grade'] == '9th'), ['math_score']] = np.nan

# %%
#  Step 4. Check the student data for NaN's. 
student_data_df.tail(10)
# Out:
#        Student ID     student_name gender grade         school_name  \
# 39160       39160     Katie Weaver      F  11th  Thomas High School
# 39161       39161      April Reyes      F  10th  Thomas High School
# 39162       39162      Derek Weeks      M  12th  Thomas High School
# 39163       39163       John Reese      M  11th  Thomas High School
# 39164       39164   Joseph Anthony      M   9th  Thomas High School
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 39160           89.0        86.0
# 39161           70.0        84.0
# 39162           94.0        77.0
# 39163           90.0        75.0
# 39164            NaN         NaN
# 39165           99.0        90.0
# 39166           95.0        70.0
# 39167            NaN         NaN
# 39168           99.0        90.0
# 39169           95.0        75.0

# %% [markdown]
# ## Deliverable 2 : Repeat the school district analysis

# %% [markdown]
# ### District Summary

# %%
# Combine the data into a single dataset
school_data_complete_df = pd.merge(student_data_df, school_data_df, how="left", on=["school_name", "school_name"])
school_data_complete_df.head()
# Out:
#    Student ID     student_name gender grade        school_name  reading_score  \
# 0           0     Paul Bradley      M   9th  Huang High School           66.0
# 1           1     Victor Smith      M  12th  Huang High School           94.0
# 2           2  Kevin Rodriguez      M  12th  Huang High School           90.0
# 3           3    Richard Scott      M  12th  Huang High School           67.0
# 4           4       Bonnie Ray      F   9th  Huang High School           97.0
#
#    math_score  School ID      type  size   budget
# 0        79.0          0  District  2917  1910635
# 1        61.0          0  District  2917  1910635
# 2        60.0          0  District  2917  1910635
# 3        58.0          0  District  2917  1910635
# 4        84.0          0  District  2917  1910635

# %%
# Calculate the Totals (Schools and Students)
school_count = len(school_data_complete_df["school_name"].unique())
student_count = school_data_complete_df["Student ID"].count()

# Calculate the Total Budget
total_budget = school_data_df["budget"].sum()

# %%
# Calculate the Average Scores using the "clean_student_data".
average_reading_score = school_data_complete_df["reading_score"].mean()
average_math_score = school_data_complete_df["math_score"].mean()

# %%
# Step 1. Get the number of students that are in ninth grade at Thomas High School.
# These students have no grades. 
ninth_grade_thomas = student_data_df.loc[(student_data_df["grade"]== "9th")&(student_data_df["school_name"]=="Thomas High School")].count()['Student ID']

# Get the total student count 
student_count = school_data_complete_df["Student ID"].count()


# Step 2. Subtract the number of students that are in ninth grade at 
# Thomas High School from the total student count to get the new total student count.
new_count = student_count - ninth_grade_thomas
print(new_count)
# Out:
# 38709

# %%
# Calculate the passing rates using the "clean_student_data".
passing_math_count = school_data_complete_df[(school_data_complete_df["math_score"] >= 70)].count()["student_name"]
passing_reading_count = school_data_complete_df[(school_data_complete_df["reading_score"] >= 70)].count()["student_name"]

# %%
# Step 3. Calculate the passing percentages with the new total student count.
passing_math_percentage = passing_math_count / new_count * 100
passing_reading_percentage = passing_reading_count / new_count * 100

# %%
# Calculate the students who passed both reading and math.
passing_math_reading = school_data_complete_df[(school_data_complete_df["math_score"] >= 70)
                                               & (school_data_complete_df["reading_score"] >= 70)]

# Calculate the number of students that passed both reading and math.
overall_passing_math_reading_count = passing_math_reading["student_name"].count()


# Step 4.Calculate the overall passing percentage with new total student count.
overall_passing_percentage = overall_passing_math_reading_count / new_count * 100

# %%
# Create a DataFrame
district_summary_df = pd.DataFrame(
          [{"Total Schools": school_count, 
          "Total Students": student_count, 
          "Total Budget": total_budget,
          "Average Math Score": average_math_score, 
          "Average Reading Score": average_reading_score,
          "% Passing Math": passing_math_percentage,
         "% Passing Reading": passing_reading_percentage,
        "% Overall Passing": overall_passing_percentage}])



# Format the "Total Students" to have the comma for a thousands separator.
district_summary_df["Total Students"] = district_summary_df["Total Students"].map("{:,}".format)
# Format the "Total Budget" to have the comma for a thousands separator, a decimal separator and a "$".
district_summary_df["Total Budget"] = district_summary_df["Total Budget"].map("${:,.2f}".format)
# Format the columns.
district_summary_df["Average Math Score"] = district_summary_df["Average Math Score"].map("{:.1f}".format)
district_summary_df["Average Reading Score"] = district_summary_df["Average Reading Score"].map("{:.1f}".format)
district_summary_df["% Passing Math"] = district_summary_df["% Passing Math"].map("{:.1f}".format)
district_summary_df["% Passing Reading"] = district_summary_df["% Passing Reading"].map("{:.1f}".format)
district_summary_df["% Overall Passing"] = district_summary_df["% Overall Passing"].map("{:.1f}".format)

# Display the data frame
district_summary_df
# Out:
#    Total Schools Total Students    Total Budget Average Math Score  \
# 0             15         39,170  $24,649,428.00               78.9
#
#   Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                  81.9           74.8              85.7              64.9

# %% [markdown]
# ##  School Summary

# %%
# Determine the School Type
per_school_types = school_data_df.set_index(["school_name"])["type"]

# Calculate the total student count.
per_school_counts = school_data_complete_df["school_name"].value_counts()

# Calculate the total school budget and per capita spending
per_school_budget = school_data_complete_df.groupby(["school_name"]).mean()["budget"]
# Calculate the per capita spending.
per_school_capita = per_school_budget / per_school_counts

# Calculate the average test scores.
per_school_math = school_data_complete_df.groupby(["school_name"]).mean()["math_score"]
per_school_reading = school_data_complete_df.groupby(["school_name"]).mean()["reading_score"]

# Calculate the passing scores by creating a filtered DataFrame.
per_school_passing_math = school_data_complete_df[(school_data_complete_df["math_score"] >= 70)]
per_school_passing_reading = school_data_complete_df[(school_data_complete_df["reading_score"] >= 70)]

# Calculate the number of students passing math and passing reading by school.
per_school_passing_math = per_school_passing_math.groupby(["school_name"]).count()["student_name"]
per_school_passing_reading = per_school_passing_reading.groupby(["school_name"]).count()["student_name"]

# Calculate the percentage of passing math and reading scores per school.
per_school_passing_math = per_school_passing_math / per_school_counts * 100
per_school_passing_reading = per_school_passing_reading / per_school_counts * 100

# Calculate the students who passed both reading and math.
per_passing_math_reading = school_data_complete_df[(school_data_complete_df["reading_score"] >= 70)
                                               & (school_data_complete_df["math_score"] >= 70)]

# Calculate the number of students passing math and passing reading by school.
per_passing_math_reading = per_passing_math_reading.groupby(["school_name"]).count()["student_name"]

# Calculate the percentage of passing math and reading scores per school.
per_overall_passing_percentage = per_passing_math_reading / per_school_counts * 100

# %%
# Create the DataFrame
per_school_summary_df = pd.DataFrame({
    "School Type": per_school_types,
    "Total Students": per_school_counts,
    "Total School Budget": per_school_budget,
    "Per Student Budget": per_school_capita,
    "Average Math Score": per_school_math,
    "Average Reading Score": per_school_reading,
    "% Passing Math": per_school_passing_math,
    "% Passing Reading": per_school_passing_reading,
    "% Overall Passing": per_overall_passing_percentage})


# per_school_summary_df.head()

# %%
# Format the Total School Budget and the Per Student Budget
per_school_summary_df["Total School Budget"] = per_school_summary_df["Total School Budget"].map("${:,.2f}".format)
per_school_summary_df["Per Student Budget"] = per_school_summary_df["Per Student Budget"].map("${:,.2f}".format)

# Display the data frame
per_school_summary_df
# Out:
#                       School Type  Total Students Total School Budget  \
# Bailey High School       District            4976       $3,124,928.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Figueroa High School     District            2949       $1,884,411.00
# Ford High School         District            2739       $1,763,916.00
# Griffin High School       Charter            1468         $917,500.00
# Hernandez High School    District            4635       $3,022,020.00
# Holden High School        Charter             427         $248,087.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Pena High School          Charter             962         $585,858.00
# Rodriguez High School    District            3999       $2,547,363.00
# Shelton High School       Charter            1761       $1,056,600.00
# Thomas High School        Charter            1635       $1,043,130.00
# Wilson High School        Charter            2283       $1,319,574.00
# Wright High School        Charter            1800       $1,049,400.00
#
#                       Per Student Budget  Average Math Score  \
# Bailey High School               $628.00           77.048432
# Cabrera High School              $582.00           83.061895
# Figueroa High School             $639.00           76.711767
# Ford High School                 $644.00           77.102592
# Griffin High School              $625.00           83.351499
# Hernandez High School            $652.00           77.289752
# Holden High School               $581.00           83.803279
# Huang High School                $655.00           76.629414
# Johnson High School              $650.00           77.072464
# Pena High School                 $609.00           83.839917
# Rodriguez High School            $637.00           76.842711
# Shelton High School              $600.00           83.359455
# Thomas High School               $638.00           83.350937
# Wilson High School               $578.00           83.274201
# Wright High School               $583.00           83.682222
#
#                        Average Reading Score  % Passing Math  \
# Bailey High School                 81.033963       66.680064
# Cabrera High School                83.975780       94.133477
# Figueroa High School               81.158020       65.988471
# Ford High School                   80.746258       68.309602
# Griffin High School                83.816757       93.392371
# Hernandez High School              80.934412       66.752967
# Holden High School                 83.814988       92.505855
# Huang High School                  81.182722       65.683922
# Johnson High School                80.966394       66.057551
# Pena High School                   84.044699       94.594595
# Rodriguez High School              80.744686       66.366592
# Shelton High School                83.725724       93.867121
# Thomas High School                 83.896082       66.911315
# Wilson High School                 83.989488       93.867718
# Wright High School                 83.955000       93.333333
#
#                        % Passing Reading  % Overall Passing
# Bailey High School             81.933280          54.642283
# Cabrera High School            97.039828          91.334769
# Figueroa High School           80.739234          53.204476
# Ford High School               79.299014          54.289887
# Griffin High School            97.138965          90.599455
# Hernandez High School          80.862999          53.527508
# Holden High School             96.252927          89.227166
# Huang High School              81.316421          53.513884
# Johnson High School            81.222432          53.539172
# Pena High School               95.945946          90.540541
# Rodriguez High School          80.220055          52.988247
# Shelton High School            95.854628          89.892107
# Thomas High School             69.663609          65.076453
# Wilson High School             96.539641          90.582567
# Wright High School             96.611111          90.333333

# %%
# Step 5.  Get the number of 10th-12th graders from Thomas High School (THS).
tenth_graders = school_data_complete_df.loc[(school_data_complete_df["grade"]== "10th") & (school_data_complete_df["school_name"]=="Thomas High School")].count()['Student ID']
eleventh_graders = school_data_complete_df.loc[(school_data_complete_df["grade"]== "11th") & (school_data_complete_df["school_name"]=="Thomas High School")].count()['Student ID']
twelfth_graders = school_data_complete_df.loc[(school_data_complete_df["grade"]== "12th") & (school_data_complete_df["school_name"]=="Thomas High School")].count()['Student ID']

total_students = tenth_graders + eleventh_graders + twelfth_graders
total_students
# Out:
# 1174

# %%
# Step 6. Get all the students passing math from THS
passing_math = school_data_complete_df.loc[(school_data_complete_df["school_name"]=="Thomas High School") & (school_data_complete_df["math_score"] >= 70)].count()["Student ID"]
passing_math
# Out:
# 1094

# %%
# Step 7. Get all the students passing reading from THS
passing_reading = school_data_complete_df.loc[(school_data_complete_df["school_name"]=="Thomas High School") & (school_data_complete_df["reading_score"] >= 70)].count()["Student ID"]
passing_reading
# Out:
# 1139

# %%
# Step 8. Get all the students passing math and reading from THS
total_students_passing = school_data_complete_df.loc[(school_data_complete_df["math_score"] >= 70) & (school_data_complete_df["reading_score"] >= 70) & (school_data_complete_df["school_name"]=="Thomas High School")]
total_students_passing
# Out:
#        Student ID          student_name gender grade         school_name  \
# 37535       37535            Norma Mata      F  10th  Thomas High School
# 37536       37536           Cody Miller      M  11th  Thomas High School
# 37541       37541          Eric Stevens      M  10th  Thomas High School
# 37542       37542     Elizabeth Bennett      F  11th  Thomas High School
# 37544       37544     Jacqueline Harris      F  10th  Thomas High School
# 37546       37546         Steven Hoover      M  12th  Thomas High School
# 37547       37547          Amanda Hicks      F  12th  Thomas High School
# 37548       37548            Brian Moss      M  10th  Thomas High School
# 37551       37551           Nancy Mason      F  12th  Thomas High School
# 37552       37552       Matthew Marquez      M  10th  Thomas High School
# 37553       37553         Curtis Gibson      M  10th  Thomas High School
# 37554       37554         Rebecca Brown      F  11th  Thomas High School
# 37555       37555           Chad Martin      M  11th  Thomas High School
# 37556       37556            Sarah Park      F  11th  Thomas High School
# 37557       37557       Shannon Sanchez      F  11th  Thomas High School
# 37560       37560              Kim Hall      F  11th  Thomas High School
# 37563       37563           Amy Richard      F  10th  Thomas High School
# 37565       37565          Teresa Poole      F  10th  Thomas High School
# 37566       37566      Jonathon Roberts      M  10th  Thomas High School
# 37568       37568      Jacob Mccullough      M  11th  Thomas High School
# 37570       37570        Victoria Brown      F  12th  Thomas High School
# 37571       37571        Michael Murphy      M  12th  Thomas High School
# 37574       37574            Mark Weeks      M  10th  Thomas High School
# 37575       37575      Monique Shepherd      F  10th  Thomas High School
# 37576       37576      Stephanie Arroyo      F  11th  Thomas High School
# 37577       37577        Tiffany Graham      F  10th  Thomas High School
# 37579       37579        Stephen Walker      M  11th  Thomas High School
# 37580       37580            Oscar Hill      M  10th  Thomas High School
# 37582       37582            Adam Gibbs      M  12th  Thomas High School
# 37583       37583      Stephanie Hayden      F  12th  Thomas High School
# 37584       37584     Alejandro Wheeler      M  10th  Thomas High School
# 37585       37585        Angela Edwards      F  12th  Thomas High School
# 37586       37586       Alexander Watts      M  10th  Thomas High School
# 37588       37588     Christopher Riley      M  12th  Thomas High School
# 37589       37589           Keith Scott      M  11th  Thomas High School
# 37590       37590        Anthony Valdez      M  11th  Thomas High School
# 37591       37591       Matthew Carroll      M  12th  Thomas High School
# 37592       37592         Kimberly Wong      F  10th  Thomas High School
# 37593       37593           James Riley      M  12th  Thomas High School
# 37594       37594          Brenda Bruce      F  10th  Thomas High School
# 37595       37595            Mary Smith      F  11th  Thomas High School
# 37596       37596        Brian Robinson      M  12th  Thomas High School
# 37597       37597       Jessica Morales      F  10th  Thomas High School
# 37598       37598      Jeffery Calderon      M  10th  Thomas High School
# 37600       37600         Jasmine Jones      F  10th  Thomas High School
# 37601       37601       Keith Maldonado      M  11th  Thomas High School
# 37602       37602         Mark Anderson      M  10th  Thomas High School
# 37604       37604         Phillip Meyer      M  11th  Thomas High School
# 37606       37606         David Aguilar      M  12th  Thomas High School
# 37607       37607      Andrew Jefferson      M  10th  Thomas High School
# 37608       37608          Dennis Perez      M  11th  Thomas High School
# 37611       37611       Adrian Martinez      M  10th  Thomas High School
# 37612       37612           Brian Kirby      M  11th  Thomas High School
# 37615       37615        Denise Estrada      F  10th  Thomas High School
# 37619       37619          Laura Nelson      F  10th  Thomas High School
# 37620       37620        Andrew Raymond      M  10th  Thomas High School
# 37621       37621     Christopher Grant      M  10th  Thomas High School
# 37622       37622       Samantha Medina      F  11th  Thomas High School
# 37623       37623          Cheryl Lopez      F  10th  Thomas High School
# 37624       37624         Thomas Little      M  12th  Thomas High School
# 37625       37625           Alyssa Hill      F  11th  Thomas High School
# 37626       37626           Sarah Moore      F  11th  Thomas High School
# 37628       37628           Travis Cole      M  12th  Thomas High School
# 37629       37629          Bobby Fisher      M  12th  Thomas High School
# 37630       37630        Morgan Collins      F  12th  Thomas High School
# 37631       37631          Robert Reyes      M  10th  Thomas High School
# 37633       37633         Benjamin King      M  10th  Thomas High School
# 37634       37634       Nathaniel Bates      M  11th  Thomas High School
# 37636       37636      Christian Warren      M  12th  Thomas High School
# 37637       37637            Ellen Paul      F  11th  Thomas High School
# 37638       37638           Mario Smith      M  11th  Thomas High School
# 37639       37639            Susan Levy      F  12th  Thomas High School
# 37640       37640         Tiffany Young      F  11th  Thomas High School
# 37642       37642      Kenneth Williams      M  11th  Thomas High School
# 37643       37643         Mark Lucas IV      M  12th  Thomas High School
# 37645       37645            John Wolfe      M  10th  Thomas High School
# 37648       37648       Kenneth Marquez      M  10th  Thomas High School
# 37651       37651        Deborah Reilly      F  11th  Thomas High School
# 37652       37652           Mike Santos      M  12th  Thomas High School
# 37654       37654      Morgan Alexander      F  10th  Thomas High School
# 37655       37655      Cristian Aguilar      M  10th  Thomas High School
# 37656       37656       Danielle Prince      F  10th  Thomas High School
# 37659       37659           Joshua Moon      M  11th  Thomas High School
# 37660       37660         Kyle Townsend      M  11th  Thomas High School
# 37662       37662      Rhonda Rodriguez      F  11th  Thomas High School
# 37664       37664     Brittany Valencia      F  11th  Thomas High School
# 37668       37668       Kimberly Morris      F  10th  Thomas High School
# 37669       37669           Kirk Reilly      M  11th  Thomas High School
# 37671       37671        Albert Vaughan      M  11th  Thomas High School
# 37672       37672    Douglas Fitzgerald      M  12th  Thomas High School
# 37673       37673          Justin Smith      M  10th  Thomas High School
# 37675       37675         Philip Miller      M  12th  Thomas High School
# 37676       37676        Ronald Hartman      M  12th  Thomas High School
# 37677       37677      Angelica Sanders      F  10th  Thomas High School
# 37678       37678            Marc Moore      M  10th  Thomas High School
# 37680       37680          Janet Taylor      F  10th  Thomas High School
# 37681       37681       Charles Estrada      M  11th  Thomas High School
# 37685       37685            Alan Leach      M  12th  Thomas High School
# 37686       37686        Timothy Miller      M  11th  Thomas High School
# 37687       37687     Christopher Villa      M  12th  Thomas High School
# 37688       37688       Stephanie Davis      F  11th  Thomas High School
# 37689       37689          Shelby Brown      F  11th  Thomas High School
# 37691       37691            Sean Kirby      M  10th  Thomas High School
# 37693       37693          Maria Turner      F  11th  Thomas High School
# 37695       37695      Keith Newman Jr.      M  12th  Thomas High School
# 37696       37696          Thomas Brown      M  10th  Thomas High School
# 37697       37697      Marcus Fernandez      M  10th  Thomas High School
# 37699       37699        Rodney Johnson      M  12th  Thomas High School
# 37700       37700      Timothy Martinez      M  11th  Thomas High School
# 37702       37702      Michael Jennings      M  12th  Thomas High School
# 37705       37705        Gabrielle Huff      F  11th  Thomas High School
# 37706       37706            Samuel Ray      M  10th  Thomas High School
# 37707       37707         Hannah Bishop      F  12th  Thomas High School
# 37709       37709            Kathy King      F  11th  Thomas High School
# 37710       37710           Alexis Cook      F  12th  Thomas High School
# 37714       37714           Lauren Carr      F  10th  Thomas High School
# 37716       37716         Michael Clark      M  10th  Thomas High School
# 37717       37717        Calvin Hawkins      M  11th  Thomas High School
# 37718       37718         Sandra Pineda      F  10th  Thomas High School
# 37720       37720     Jessica Hernandez      F  10th  Thomas High School
# 37722       37722    Christopher Campos      M  10th  Thomas High School
# 37724       37724     Danielle Sheppard      F  12th  Thomas High School
# 37725       37725       Micheal Johnson      M  10th  Thomas High School
# 37727       37727      Margaret Russell      F  10th  Thomas High School
# 37728       37728           James Adams      M  11th  Thomas High School
# 37730       37730            John Bauer      M  10th  Thomas High School
# 37732       37732         Connor Sutton      M  10th  Thomas High School
# 37738       37738      Jeanette Roberts      F  12th  Thomas High School
# 37739       37739         Janet Benitez      F  12th  Thomas High School
# 37740       37740         Taylor Martin      M  12th  Thomas High School
# 37743       37743       Joseph Peterson      M  10th  Thomas High School
# 37745       37745            Brian Shaw      M  12th  Thomas High School
# 37746       37746        Heidi Crawford      F  11th  Thomas High School
# 37747       37747        Kenneth Crosby      M  11th  Thomas High School
# 37750       37750    Christopher Miller      M  11th  Thomas High School
# 37751       37751         Frank Sanders      M  12th  Thomas High School
# 37753       37753      Anthony Cummings      M  11th  Thomas High School
# 37754       37754           Breanna Lee      F  11th  Thomas High School
# 37755       37755          Kyle Rowland      M  10th  Thomas High School
# 37758       37758       Devon Contreras      M  11th  Thomas High School
# 37760       37760        Matthew Deleon      M  11th  Thomas High School
# 37761       37761          Erica Martin      F  11th  Thomas High School
# 37762       37762         Matthew Jones      M  11th  Thomas High School
# 37763       37763      Michael Martinez      M  10th  Thomas High School
# 37764       37764        Jennifer Clark      F  10th  Thomas High School
# 37765       37765        Jennifer Lewis      F  12th  Thomas High School
# 37766       37766           Terry Woods      M  11th  Thomas High School
# 37767       37767           Misty Klein      F  12th  Thomas High School
# 37768       37768         David Stevens      M  10th  Thomas High School
# 37769       37769      Natalie Gonzales      F  11th  Thomas High School
# 37770       37770         Ashley Willis      F  11th  Thomas High School
# 37772       37772    Jennifer Rodriguez      F  12th  Thomas High School
# 37774       37774          Martha Brown      F  10th  Thomas High School
# 37775       37775           Robert Beck      M  10th  Thomas High School
# 37777       37777       Hannah Mcdonald      F  12th  Thomas High School
# 37779       37779          Katie Nelson      F  12th  Thomas High School
# 37781       37781       Timothy Aguirre      M  12th  Thomas High School
# 37784       37784        Jonathan Davis      M  12th  Thomas High School
# 37786       37786      Theresa Thompson      F  10th  Thomas High School
# 37787       37787           Paul Brooks      M  10th  Thomas High School
# 37788       37788        Brandon Palmer      M  11th  Thomas High School
# 37790       37790       Dustin Thompson      M  11th  Thomas High School
# 37791       37791        Grant Gallegos      M  11th  Thomas High School
# 37793       37793          Edward Allen      M  10th  Thomas High School
# 37796       37796     Stephanie Nichols      F  12th  Thomas High School
# 37797       37797        Kathy Roberson      F  10th  Thomas High School
# 37798       37798       Justin Thompson      M  10th  Thomas High School
# 37800       37800        Pamela Bradley      F  11th  Thomas High School
# 37801       37801          Nancy Cannon      F  11th  Thomas High School
# 37802       37802          Ashley Lopez      F  10th  Thomas High School
# 37803       37803           Linda Roman      F  12th  Thomas High School
# 37804       37804          Cheryl Quinn      F  12th  Thomas High School
# 37805       37805        Joseph Sellers      M  11th  Thomas High School
# 37808       37808        Angela Summers      F  10th  Thomas High School
# 37811       37811      Catherine Howard      F  11th  Thomas High School
# 37813       37813      Jessica Morrison      F  11th  Thomas High School
# 37814       37814       Susan Alexander      F  11th  Thomas High School
# 37815       37815       Jessica Edwards      F  11th  Thomas High School
# 37816       37816        Benjamin Evans      M  10th  Thomas High School
# 37817       37817        Mariah Bernard      F  11th  Thomas High School
# 37818       37818          Morgan Scott      F  11th  Thomas High School
# 37819       37819    Nicholas Hernandez      M  10th  Thomas High School
# 37822       37822            Regina Ray      F  10th  Thomas High School
# 37828       37828        Kathleen Black      F  10th  Thomas High School
# 37830       37830           Julie Villa      F  11th  Thomas High School
# 37831       37831            Paula Reed      F  11th  Thomas High School
# 37832       37832         Grace Russell      F  12th  Thomas High School
# 37833       37833         Barbara Smith      F  10th  Thomas High School
# 37835       37835             Jason Lee      M  12th  Thomas High School
# 37836       37836         Rodney Wilson      M  12th  Thomas High School
# 37837       37837         Allison Combs      F  11th  Thomas High School
# 37838       37838         Ralph Osborne      M  11th  Thomas High School
# 37839       37839        Samuel Johnson      M  10th  Thomas High School
# 37841       37841      Matthew Anderson      M  11th  Thomas High School
# 37842       37842          Sarah Chavez      F  12th  Thomas High School
# 37843       37843         Paul Cisneros      M  12th  Thomas High School
# 37845       37845       Eric Strickland      M  11th  Thomas High School
# 37846       37846       Katherine Brown      F  11th  Thomas High School
# 37847       37847        Mike Schneider      M  10th  Thomas High School
# 37848       37848          Brian Mendez      M  12th  Thomas High School
# 37851       37851           Kevin Gomez      M  12th  Thomas High School
# 37852       37852        Courtney Smith      F  12th  Thomas High School
# 37853       37853         Julie Walters      F  11th  Thomas High School
# 37854       37854          Linda Dillon      F  12th  Thomas High School
# 37855       37855      Christine Harris      F  12th  Thomas High School
# 37856       37856           Amy Sanders      F  12th  Thomas High School
# 37857       37857         Daniel Arnold      M  10th  Thomas High School
# 37859       37859         Wayne Gilbert      M  11th  Thomas High School
# 37860       37860           Billy Baker      M  11th  Thomas High School
# 37861       37861       Lorraine Atkins      F  11th  Thomas High School
# 37862       37862        Hunter Hensley      M  11th  Thomas High School
# 37863       37863         Harold Parker      M  10th  Thomas High School
# 37867       37867        Ashley Alvarez      F  10th  Thomas High School
# 37868       37868          Kenneth Ruiz      M  10th  Thomas High School
# 37869       37869         Michael Clark      M  12th  Thomas High School
# 37870       37870         Dale Martinez      M  10th  Thomas High School
# 37871       37871          Brandon Levy      M  10th  Thomas High School
# 37874       37874     Michael Alexander      M  12th  Thomas High School
# 37876       37876         Randy Johnson      M  11th  Thomas High School
# 37877       37877        Vanessa Turner      F  10th  Thomas High School
# 37879       37879         Angela Taylor      F  11th  Thomas High School
# 37880       37880       Whitney Burgess      F  12th  Thomas High School
# 37881       37881          Thomas Gomez      M  11th  Thomas High School
# 37883       37883          Kevin Garcia      M  10th  Thomas High School
# 37886       37886           Joseph Diaz      M  10th  Thomas High School
# 37887       37887         Vicki Nielsen      F  12th  Thomas High School
# 37888       37888      Theresa Gonzalez      F  10th  Thomas High School
# 37890       37890         Randy Johnson      M  10th  Thomas High School
# 37891       37891             Paul Hart      M  11th  Thomas High School
# 37892       37892     Christina Barrera      F  10th  Thomas High School
# 37893       37893        Diamond Miller      F  10th  Thomas High School
# 37894       37894           Kerri Davis      F  12th  Thomas High School
# 37896       37896          Oscar Flores      M  10th  Thomas High School
# 37899       37899        James Gonzalez      M  10th  Thomas High School
# 37901       37901           Paige Hines      F  12th  Thomas High School
# 37903       37903      Victoria Simpson      F  11th  Thomas High School
# 37905       37905       Kevin Rodriguez      M  10th  Thomas High School
# 37906       37906        Janice Stewart      F  11th  Thomas High School
# 37909       37909       Ronald Franklin      M  11th  Thomas High School
# 37910       37910       Brittany Walker      F  10th  Thomas High School
# 37911       37911          Billy Curtis      M  11th  Thomas High School
# 37912       37912         Julie Wiggins      F  11th  Thomas High School
# 37913       37913          Erika Torres      F  12th  Thomas High School
# 37914       37914    Patricia Contreras      F  11th  Thomas High School
# 37915       37915          Randy Hooper      M  10th  Thomas High School
# 37917       37917           Ronald Rowe      M  10th  Thomas High School
# 37918       37918        Allison Thomas      F  10th  Thomas High School
# 37919       37919      Danielle Hawkins      F  11th  Thomas High School
# 37920       37920          Victor Smith      M  12th  Thomas High School
# 37921       37921      Colin Schultz II      M  10th  Thomas High School
# 37923       37923           Angela Wong      F  10th  Thomas High School
# 37924       37924           John Ritter      M  11th  Thomas High School
# 37925       37925       Gabriel Douglas      M  11th  Thomas High School
# 37926       37926       Sarah Mcpherson      F  10th  Thomas High School
# 37927       37927  Christopher Sandoval      M  12th  Thomas High School
# 37929       37929         Ashley Wilson      F  12th  Thomas High School
# 37931       37931           Craig Heath      M  11th  Thomas High School
# 37934       37934        Jeffrey Garcia      M  12th  Thomas High School
# 37936       37936           Michelle Li      F  10th  Thomas High School
# 37938       37938          Bryan Barnes      M  11th  Thomas High School
# 37939       37939          Robert Meyer      M  11th  Thomas High School
# 37942       37942       Neil Hutchinson      M  12th  Thomas High School
# 37943       37943          Henry Acosta      M  12th  Thomas High School
# 37944       37944      Vanessa Figueroa      F  12th  Thomas High School
# 37945       37945          Larry Harris      M  10th  Thomas High School
# 37946       37946    Kristopher Bradley      M  11th  Thomas High School
# 37947       37947           Bruce White      M  11th  Thomas High School
# 37948       37948       Danielle Holmes      F  10th  Thomas High School
# 37949       37949           Jamie Allen      F  11th  Thomas High School
# 37952       37952       Ashley Thompson      F  12th  Thomas High School
# 37953       37953      Stephanie Knight      F  11th  Thomas High School
# 37954       37954          Cameron Rowe      M  10th  Thomas High School
# 37955       37955        Michael Farmer      M  12th  Thomas High School
# 37957       37957        Bernard Mercer      M  11th  Thomas High School
# 37959       37959           Kent Becker      M  10th  Thomas High School
# 37960       37960        David Campbell      M  10th  Thomas High School
# 37965       37965        Andrew Summers      M  12th  Thomas High School
# 37966       37966      Jennifer Sanders      F  10th  Thomas High School
# 37967       37967           April Smith      F  12th  Thomas High School
# 37968       37968         Claire Murray      F  12th  Thomas High School
# 37970       37970        Stephen Arnold      M  12th  Thomas High School
# 37971       37971        Maria Crawford      F  10th  Thomas High School
# 37972       37972        Anthony Walker      M  11th  Thomas High School
# 37974       37974         Brian Johnson      M  12th  Thomas High School
# 37975       37975      Brittney Ramirez      F  11th  Thomas High School
# 37976       37976           Austin King      M  11th  Thomas High School
# 37977       37977        Joshua Hammond      M  11th  Thomas High School
# 37978       37978            Erika Wood      F  12th  Thomas High School
# 37982       37982          Monica Evans      F  10th  Thomas High School
# 37983       37983         Joseph Willis      M  10th  Thomas High School
# 37985       37985         Gabriel Hayes      M  11th  Thomas High School
# 37987       37987           Angela Diaz      F  11th  Thomas High School
# 37988       37988         Michael Ortiz      M  11th  Thomas High School
# 37990       37990         Susan Gregory      F  11th  Thomas High School
# 37992       37992         Jacob Sanchez      M  10th  Thomas High School
# 37994       37994          Kevin Rivera      M  10th  Thomas High School
# 37995       37995            Jose Smith      M  12th  Thomas High School
# 37998       37998           Deanna Ford      F  10th  Thomas High School
# 38000       38000          Antonio Dunn      M  12th  Thomas High School
# 38002       38002           Keith Smith      M  11th  Thomas High School
# 38003       38003         Steven Holmes      M  12th  Thomas High School
# 38004       38004         Ashley Mendez      F  12th  Thomas High School
# 38006       38006           Paul Torres      M  10th  Thomas High School
# 38009       38009        Timothy Benson      M  12th  Thomas High School
# 38011       38011         Sara Robinson      F  11th  Thomas High School
# 38012       38012        Donna Phillips      F  12th  Thomas High School
# 38015       38015         Gary Santiago      M  10th  Thomas High School
# 38016       38016        Theresa Sparks      F  10th  Thomas High School
# 38018       38018            Amber Hood      F  12th  Thomas High School
# 38019       38019      Robert Wilkinson      M  11th  Thomas High School
# 38020       38020            Jade Black      F  10th  Thomas High School
# 38021       38021             Amy Kirby      F  12th  Thomas High School
# 38022       38022         Amanda Fields      F  10th  Thomas High School
# 38023       38023        Caroline Smith      F  12th  Thomas High School
# 38024       38024        Michael Knight      M  12th  Thomas High School
# 38026       38026        Samantha Stone      F  10th  Thomas High School
# 38030       38030         Chris Bennett      M  11th  Thomas High School
# 38031       38031        Jeffrey Hudson      M  11th  Thomas High School
# 38032       38032          Anthony Bell      M  12th  Thomas High School
# 38033       38033      Angela Rodriguez      F  11th  Thomas High School
# 38034       38034      Suzanne Odonnell      F  10th  Thomas High School
# 38036       38036         Crystal Hodge      F  11th  Thomas High School
# 38040       38040         Holly Coleman      F  11th  Thomas High School
# 38044       38044        Patricia Lewis      F  12th  Thomas High School
# 38045       38045             Paul Paul      M  11th  Thomas High School
# 38048       38048         April Ellison      F  11th  Thomas High School
# 38049       38049       Danielle Jensen      F  10th  Thomas High School
# 38050       38050       Denise Thompson      F  11th  Thomas High School
# 38051       38051       Thomas Phillips      M  11th  Thomas High School
# 38053       38053        Brianna Martin      F  12th  Thomas High School
# 38054       38054     William Patterson      M  11th  Thomas High School
# 38055       38055           Rachel Hill      F  10th  Thomas High School
# 38056       38056      Marissa Martinez      F  12th  Thomas High School
# 38064       38064           Kevin Smith      M  12th  Thomas High School
# 38065       38065          Jordan Jones      F  10th  Thomas High School
# 38066       38066          Kyle Sanchez      M  12th  Thomas High School
# 38067       38067        Jeremy Aguilar      M  11th  Thomas High School
# 38069       38069       Jennifer Rogers      F  11th  Thomas High School
# 38070       38070         Kristie Duffy      F  11th  Thomas High School
# 38071       38071            Blake Pope      M  11th  Thomas High School
# 38074       38074        Brittney Bates      F  11th  Thomas High School
# 38075       38075         Edward Howard      M  12th  Thomas High School
# 38077       38077       Courtney Turner      F  12th  Thomas High School
# 38078       38078       Cynthia Mcbride      F  10th  Thomas High School
# 38080       38080         William Ellis      M  11th  Thomas High School
# 38081       38081      Stephanie Nguyen      F  11th  Thomas High School
# 38082       38082       Michael Walters      M  11th  Thomas High School
# 38084       38084        John Hernandez      M  12th  Thomas High School
# 38086       38086          George Hobbs      M  10th  Thomas High School
# 38090       38090          Carol Valdez      F  11th  Thomas High School
# 38092       38092        Misty Anderson      F  11th  Thomas High School
# 38093       38093        William Jordan      M  10th  Thomas High School
# 38094       38094         William Potts      M  10th  Thomas High School
# 38095       38095           Jay Johnson      M  12th  Thomas High School
# 38096       38096        Kristina Mason      F  12th  Thomas High School
# 38097       38097       Kimberly Conway      F  10th  Thomas High School
# 38098       38098         Rebecca Jones      F  12th  Thomas High School
# 38099       38099        Gina Hernandez      F  12th  Thomas High School
# 38101       38101       Brenda Holloway      F  11th  Thomas High School
# 38106       38106            Adam Lynch      M  11th  Thomas High School
# 38107       38107       David Gutierrez      M  10th  Thomas High School
# 38109       38109         Brandon Tapia      M  11th  Thomas High School
# 38110       38110       Isabel Bradford      F  12th  Thomas High School
# 38111       38111       Phillip Beasley      M  12th  Thomas High School
# 38112       38112           Aimee Olsen      F  11th  Thomas High School
# 38114       38114             Mary Pace      F  11th  Thomas High School
# 38117       38117           Sarah Cohen      F  11th  Thomas High School
# 38119       38119            Wanda Hall      F  11th  Thomas High School
# 38120       38120            Glenn Howe      M  11th  Thomas High School
# 38121       38121            Brian Bell      M  12th  Thomas High School
# 38124       38124            Blake Horn      M  11th  Thomas High School
# 38125       38125          Jessica Kidd      F  11th  Thomas High School
# 38128       38128     Christopher Jones      M  11th  Thomas High School
# 38129       38129          Ashley Brown      F  10th  Thomas High School
# 38130       38130          William Wolf      M  12th  Thomas High School
# 38132       38132             Colton Le      M  10th  Thomas High School
# 38134       38134              David Wu      M  11th  Thomas High School
# 38137       38137      Jeffrey Anderson      M  11th  Thomas High School
# 38138       38138          Thomas Perez      M  12th  Thomas High School
# 38142       38142         George Bailey      M  12th  Thomas High School
# 38143       38143       Richard Mullins      M  11th  Thomas High School
# 38146       38146            Ryan Munoz      M  11th  Thomas High School
# 38148       38148    Benjamin Singleton      M  10th  Thomas High School
# 38149       38149            Megan Soto      F  11th  Thomas High School
# 38150       38150        Jillian Ashley      F  10th  Thomas High School
# 38151       38151          Maria Foster      F  10th  Thomas High School
# 38152       38152            Riley Horn      M  10th  Thomas High School
# 38153       38153        Andrew Daniels      M  11th  Thomas High School
# 38154       38154     Madison Castaneda      F  10th  Thomas High School
# 38155       38155          Krystal Reid      F  11th  Thomas High School
# 38157       38157           Chad Hurley      M  12th  Thomas High School
# 38158       38158           Dwayne Soto      M  10th  Thomas High School
# 38161       38161      Claudia Johnston      F  12th  Thomas High School
# 38162       38162      Stephanie Bailey      F  10th  Thomas High School
# 38163       38163           Kevin Mejia      M  12th  Thomas High School
# 38164       38164        Robert Aguilar      M  10th  Thomas High School
# 38165       38165           Beverly Cox      F  11th  Thomas High School
# 38167       38167       Michelle Morris      F  12th  Thomas High School
# 38168       38168      Timothy Melendez      M  10th  Thomas High School
# 38169       38169         Regina Reeves      F  10th  Thomas High School
# 38170       38170       Crystal Goodwin      F  12th  Thomas High School
# 38171       38171         Alison Hunter      F  12th  Thomas High School
# 38172       38172        Kayla Anderson      F  10th  Thomas High School
# 38173       38173           Kara Spears      F  11th  Thomas High School
# 38174       38174     Michelle Peterson      F  12th  Thomas High School
# 38176       38176        Phillip Thomas      M  12th  Thomas High School
# 38177       38177          Teresa Smith      F  11th  Thomas High School
# 38178       38178             Kim Smith      F  10th  Thomas High School
# 38180       38180             David Cox      M  11th  Thomas High School
# 38181       38181         Lauren Barton      F  11th  Thomas High School
# 38182       38182         Joshua Little      M  12th  Thomas High School
# 38183       38183          Marie Miller      F  11th  Thomas High School
# 38184       38184        Richard Miller      M  12th  Thomas High School
# 38188       38188         James Aguilar      M  10th  Thomas High School
# 38191       38191           Karen Ellis      F  10th  Thomas High School
# 38193       38193       Breanna Aguilar      F  10th  Thomas High School
# 38194       38194      Andrew Dickerson      M  12th  Thomas High School
# 38196       38196       Johnny Matthews      M  11th  Thomas High School
# 38197       38197         Valerie Woods      F  11th  Thomas High School
# 38198       38198        Tamara Watkins      F  11th  Thomas High School
# 38199       38199          Lisa Carlson      F  12th  Thomas High School
# 38200       38200          David Becker      M  10th  Thomas High School
# 38201       38201        Nathaniel Wood      M  12th  Thomas High School
# 38202       38202           Eric Barton      M  10th  Thomas High School
# 38203       38203          Brianna Lynn      F  10th  Thomas High School
# 38204       38204           Emily James      F  12th  Thomas High School
# 38205       38205      Jeremy Hernandez      M  10th  Thomas High School
# 38206       38206           Traci White      F  10th  Thomas High School
# 38209       38209         Kimberly Bond      F  10th  Thomas High School
# 38210       38210      Darrell Oconnell      M  11th  Thomas High School
# 38211       38211          Anthony Page      M  11th  Thomas High School
# 38212       38212        Richard Prince      M  11th  Thomas High School
# 38216       38216          Robert Moore      M  11th  Thomas High School
# 38217       38217            Lisa Moore      F  10th  Thomas High School
# 38218       38218         Marcus Romero      M  11th  Thomas High School
# 38219       38219        Crystal Oliver      F  12th  Thomas High School
# 38220       38220           Carrie Mora      F  12th  Thomas High School
# 38221       38221         Kevin Stewart      M  12th  Thomas High School
# 38223       38223      Christina Rivera      F  12th  Thomas High School
# 38226       38226            Lisa Brown      F  10th  Thomas High School
# 38227       38227          Kristi Wells      F  10th  Thomas High School
# 38229       38229         Collin Harvey      M  11th  Thomas High School
# 38230       38230       Edward Anderson      M  12th  Thomas High School
# 38231       38231        Amanda Morales      F  11th  Thomas High School
# 38232       38232          Daniel Brown      M  10th  Thomas High School
# 38234       38234           Nicole Rowe      F  10th  Thomas High School
# 38236       38236     Christopher Perry      M  12th  Thomas High School
# 38237       38237          Mark Nichols      M  10th  Thomas High School
# 38239       38239       Nathaniel Owens      M  10th  Thomas High School
# 38240       38240        Kristi Sanchez      F  12th  Thomas High School
# 38241       38241         Jennifer Hunt      F  11th  Thomas High School
# 38243       38243        Kristen Garcia      F  11th  Thomas High School
# 38244       38244         Erica Watkins      F  10th  Thomas High School
# 38245       38245        Elizabeth Cook      F  11th  Thomas High School
# 38246       38246           Ryan Romero      M  11th  Thomas High School
# 38248       38248            Ann Taylor      F  11th  Thomas High School
# 38249       38249       Timothy Johnson      M  12th  Thomas High School
# 38250       38250          Victor Sharp      M  11th  Thomas High School
# 38251       38251        Stacy Oconnell      F  12th  Thomas High School
# 38253       38253        Edward Solomon      M  10th  Thomas High School
# 38254       38254       Christine Lyons      F  11th  Thomas High School
# 38255       38255        Jordan Mueller      F  10th  Thomas High School
# 38256       38256          Jessica Wade      F  10th  Thomas High School
# 38258       38258     Dorothy Cervantes      F  11th  Thomas High School
# 38259       38259       Cassandra Evans      F  10th  Thomas High School
# 38264       38264          Jesse Wilson      M  10th  Thomas High School
# 38266       38266          David Turner      M  10th  Thomas High School
# 38268       38268         Paul Thompson      M  11th  Thomas High School
# 38273       38273        Kristina Arias      F  11th  Thomas High School
# 38274       38274         Ryan Gonzalez      M  11th  Thomas High School
# 38275       38275        Wayne Shepherd      M  11th  Thomas High School
# 38276       38276      Matthew Campbell      M  10th  Thomas High School
# 38277       38277        Yolanda Brooks      F  10th  Thomas High School
# 38278       38278          Timothy Gray      M  11th  Thomas High School
# 38280       38280         Curtis Parker      M  11th  Thomas High School
# 38283       38283       Michael Hoffman      M  11th  Thomas High School
# 38284       38284       Natalie Gardner      F  10th  Thomas High School
# 38285       38285             Diane Ray      F  10th  Thomas High School
# 38286       38286             Pam Ellis      F  12th  Thomas High School
# 38288       38288           Laura Ramos      F  11th  Thomas High School
# 38289       38289       Danielle Acosta      F  12th  Thomas High School
# 38291       38291         Frank Ramirez      M  10th  Thomas High School
# 38293       38293            Tina Greer      F  11th  Thomas High School
# 38295       38295         Kristy Harris      F  11th  Thomas High School
# 38297       38297            Anna Lewis      F  12th  Thomas High School
# 38299       38299          Aaron Holmes      M  10th  Thomas High School
# 38300       38300       Michael Vasquez      M  11th  Thomas High School
# 38301       38301           Marc Snyder      M  11th  Thomas High School
# 38302       38302          Thomas Tyler      M  12th  Thomas High School
# 38303       38303        James Harrison      M  11th  Thomas High School
# 38304       38304        David Saunders      M  11th  Thomas High School
# 38305       38305        Nathaniel Carr      M  11th  Thomas High School
# 38306       38306          Adam Maxwell      M  10th  Thomas High School
# 38307       38307         Eric Williams      M  10th  Thomas High School
# 38308       38308      Chelsea Castillo      F  12th  Thomas High School
# 38309       38309           Jaime Sloan      F  10th  Thomas High School
# 38310       38310       Sarah Rodriguez      F  11th  Thomas High School
# 38311       38311     Kristina Schaefer      F  11th  Thomas High School
# 38312       38312          Diane Martin      F  12th  Thomas High School
# 38316       38316           Lisa Tucker      F  12th  Thomas High School
# 38317       38317           Renee Moore      F  10th  Thomas High School
# 38319       38319            Keith King      M  11th  Thomas High School
# 38320       38320        Amanda Skinner      F  11th  Thomas High School
# 38321       38321        Marcus Wallace      M  12th  Thomas High School
# 38323       38323       Darrell Simpson      M  10th  Thomas High School
# 38324       38324            Diane Rush      F  10th  Thomas High School
# 38326       38326            Rita Perez      F  10th  Thomas High School
# 38327       38327        Sarah Williams      F  10th  Thomas High School
# 38328       38328             Jason Key      M  12th  Thomas High School
# 38329       38329       Christine Smith      F  10th  Thomas High School
# 38330       38330        Jennifer Dixon      F  12th  Thomas High School
# 38332       38332      Maxwell Anderson      M  10th  Thomas High School
# 38333       38333    Christina Robinson      F  12th  Thomas High School
# 38336       38336          Tanya Barnes      F  11th  Thomas High School
# 38338       38338      Donald Nicholson      M  12th  Thomas High School
# 38339       38339          Nathan Smith      M  10th  Thomas High School
# 38340       38340          Sarah Briggs      F  11th  Thomas High School
# 38341       38341         Joshua Thomas      M  10th  Thomas High School
# 38343       38343           David Smith      M  12th  Thomas High School
# 38344       38344        Rebecca Reilly      F  10th  Thomas High School
# 38345       38345           Paul Bowers      M  11th  Thomas High School
# 38346       38346        Teresa Chapman      F  12th  Thomas High School
# 38347       38347         Kimberly Case      F  11th  Thomas High School
# 38349       38349         Brenda Rivera      F  10th  Thomas High School
# 38351       38351         Kenneth Simon      M  12th  Thomas High School
# 38353       38353           Scott Smith      M  11th  Thomas High School
# 38355       38355        Kayla Williams      F  11th  Thomas High School
# 38357       38357      Emily Washington      F  10th  Thomas High School
# 38358       38358      Elizabeth Graham      F  11th  Thomas High School
# 38359       38359          Kristy Perry      F  11th  Thomas High School
# 38361       38361       Brittany Harper      F  12th  Thomas High School
# 38362       38362        Robert Pollard      M  10th  Thomas High School
# 38363       38363           Heidi Gomez      F  11th  Thomas High School
# 38364       38364            Mark White      M  10th  Thomas High School
# 38365       38365          Dustin Meyer      M  10th  Thomas High School
# 38366       38366        Stephanie Pham      F  12th  Thomas High School
# 38367       38367        Jeffery Howard      M  12th  Thomas High School
# 38368       38368        Christina Owen      F  10th  Thomas High School
# 38369       38369             Ana Ellis      F  11th  Thomas High School
# 38371       38371       William Schmidt      M  12th  Thomas High School
# 38372       38372     Elizabeth Johnson      F  10th  Thomas High School
# 38373       38373          Ronald Yates      M  11th  Thomas High School
# 38375       38375       Stacey Jennings      F  11th  Thomas High School
# 38376       38376            Brandy Cox      F  11th  Thomas High School
# 38379       38379       Steven Thompson      M  11th  Thomas High School
# 38380       38380         Kaitlyn Davis      F  11th  Thomas High School
# 38381       38381       Patricia Maddox      F  10th  Thomas High School
# 38382       38382             Dylan Ray      M  11th  Thomas High School
# 38383       38383         Sharon Larson      F  12th  Thomas High School
# 38384       38384            Marc Short      M  11th  Thomas High School
# 38385       38385           John Atkins      M  12th  Thomas High School
# 38387       38387          Terry Torres      M  10th  Thomas High School
# 38388       38388             Eric Huff      M  10th  Thomas High School
# 38390       38390            Katie Neal      F  11th  Thomas High School
# 38392       38392         Daniel Wilson      M  12th  Thomas High School
# 38394       38394      Dennis Rodriguez      M  11th  Thomas High School
# 38395       38395       Elaine Stephens      F  11th  Thomas High School
# 38396       38396        Melissa Graves      F  11th  Thomas High School
# 38398       38398         Sandra Franco      F  11th  Thomas High School
# 38399       38399            Adam Woods      M  10th  Thomas High School
# 38400       38400         Patrick Joyce      M  11th  Thomas High School
# 38401       38401            Tanya Chen      F  11th  Thomas High School
# 38402       38402          Tracy Dawson      F  10th  Thomas High School
# 38404       38404          Brenda Lloyd      F  11th  Thomas High School
# 38405       38405          Brianna Frey      F  10th  Thomas High School
# 38407       38407            Megan Page      F  12th  Thomas High School
# 38408       38408           Jordan Long      M  10th  Thomas High School
# 38409       38409           Tracy Lewis      F  12th  Thomas High School
# 38410       38410     Christine Sellers      F  10th  Thomas High School
# 38412       38412          Donald Evans      M  10th  Thomas High School
# 38415       38415           David Cohen      M  10th  Thomas High School
# 38416       38416             Mark Rice      M  12th  Thomas High School
# 38422       38422          Jennifer Gay      F  12th  Thomas High School
# 38426       38426          Ashley Black      F  11th  Thomas High School
# 38427       38427           Adam Hinton      M  11th  Thomas High School
# 38428       38428       Rebecca Sanchez      F  12th  Thomas High School
# 38429       38429         Daniel Harris      M  10th  Thomas High School
# 38430       38430           Angie Vance      F  10th  Thomas High School
# 38433       38433            Scott Mack      M  11th  Thomas High School
# 38434       38434           Diane Morse      F  11th  Thomas High School
# 38435       38435          Lori Jenkins      F  11th  Thomas High School
# 38437       38437         Jonathan Dunn      M  12th  Thomas High School
# 38438       38438         Dustin Butler      M  10th  Thomas High School
# 38439       38439           Cody Cortez      M  11th  Thomas High School
# 38440       38440       Bridget Benitez      F  10th  Thomas High School
# 38441       38441         Earl Thompson      M  10th  Thomas High School
# 38442       38442        Tracie Stewart      F  10th  Thomas High School
# 38443       38443             Brenda Le      F  12th  Thomas High School
# 38445       38445       Elizabeth Stout      F  11th  Thomas High School
# 38448       38448            Drew Jones      M  10th  Thomas High School
# 38449       38449          Kevin Gordon      M  11th  Thomas High School
# 38450       38450        Andrew Anthony      M  11th  Thomas High School
# 38451       38451          David Garner      M  10th  Thomas High School
# 38452       38452         Dawn Richards      F  10th  Thomas High School
# 38453       38453       Zachary Sanchez      M  11th  Thomas High School
# 38455       38455          Heidi Rhodes      F  10th  Thomas High School
# 38456       38456       Kimberly Duncan      F  12th  Thomas High School
# 38458       38458         Scott Walters      M  11th  Thomas High School
# 38459       38459        Travis Johnson      M  10th  Thomas High School
# 38460       38460           Taylor Owen      F  10th  Thomas High School
# 38462       38462           Erin Miller      F  12th  Thomas High School
# 38464       38464         Donna Ramirez      F  12th  Thomas High School
# 38465       38465          David Taylor      M  12th  Thomas High School
# 38467       38467            John Small      M  10th  Thomas High School
# 38468       38468          Robert Lloyd      M  12th  Thomas High School
# 38469       38469             Joe Ewing      M  10th  Thomas High School
# 38470       38470        William Carter      M  12th  Thomas High School
# 38471       38471        Melinda Thomas      F  10th  Thomas High School
# 38472       38472         Jill Mckinney      F  11th  Thomas High School
# 38473       38473             John Dunn      M  10th  Thomas High School
# 38474       38474       Jordan Martinez      M  12th  Thomas High School
# 38475       38475            Mary Nixon      F  10th  Thomas High School
# 38477       38477        Ashley Jimenez      F  11th  Thomas High School
# 38479       38479         Laurie Fowler      F  12th  Thomas High School
# 38480       38480       Michael Johnson      M  10th  Thomas High School
# 38481       38481          Kevin Foster      M  12th  Thomas High School
# 38482       38482       Michael Stevens      M  10th  Thomas High School
# 38483       38483           Tracy Noble      F  10th  Thomas High School
# 38484       38484        Daniel Schultz      M  10th  Thomas High School
# 38487       38487            Paul Hayes      M  10th  Thomas High School
# 38488       38488          Glenn Mercer      M  10th  Thomas High School
# 38489       38489        Charles Flores      M  10th  Thomas High School
# 38490       38490        Melissa Wilson      F  10th  Thomas High School
# 38492       38492           John Stuart      M  12th  Thomas High School
# 38496       38496              Eric Cox      M  10th  Thomas High School
# 38497       38497          Leslie Kelly      F  10th  Thomas High School
# 38499       38499      Olivia Hernandez      F  10th  Thomas High School
# 38500       38500        Patrick Garcia      M  12th  Thomas High School
# 38501       38501        Teresa Schultz      F  10th  Thomas High School
# 38502       38502              Kim Peck      F  10th  Thomas High School
# ...
# 38829           97.0        81.0         14  Charter  1635  1043130
# 38830           84.0        98.0         14  Charter  1635  1043130
# 38832           95.0        75.0         14  Charter  1635  1043130
# 38833           91.0        91.0         14  Charter  1635  1043130
# 38834           95.0        86.0         14  Charter  1635  1043130
# 38836           84.0        70.0         14  Charter  1635  1043130
# 38837           77.0        80.0         14  Charter  1635  1043130
# 38838           95.0        80.0         14  Charter  1635  1043130
# 38840           88.0        86.0         14  Charter  1635  1043130
# 38841           84.0        98.0         14  Charter  1635  1043130
# 38842           82.0        86.0         14  Charter  1635  1043130
# 38843           86.0        89.0         14  Charter  1635  1043130
# 38844           87.0        80.0         14  Charter  1635  1043130
# 38845           81.0        84.0         14  Charter  1635  1043130
# 38846           87.0        74.0         14  Charter  1635  1043130
# 38848           92.0        83.0         14  Charter  1635  1043130
# 38849           70.0        78.0         14  Charter  1635  1043130
# 38850           78.0        76.0         14  Charter  1635  1043130
# 38851           70.0        77.0         14  Charter  1635  1043130
# 38852           88.0        83.0         14  Charter  1635  1043130
# 38853           72.0        78.0         14  Charter  1635  1043130
# 38855           70.0        91.0         14  Charter  1635  1043130
# 38856           77.0        81.0         14  Charter  1635  1043130
# 38857           87.0        76.0         14  Charter  1635  1043130
# 38860           97.0        91.0         14  Charter  1635  1043130
# 38861           72.0        90.0         14  Charter  1635  1043130
# 38862           84.0        83.0         14  Charter  1635  1043130
# 38864           70.0        70.0         14  Charter  1635  1043130
# 38866           85.0        95.0         14  Charter  1635  1043130
# 38872           85.0        92.0         14  Charter  1635  1043130
# 38873           89.0        93.0         14  Charter  1635  1043130
# 38874           72.0        94.0         14  Charter  1635  1043130
# 38875           98.0        91.0         14  Charter  1635  1043130
# 38877           79.0        91.0         14  Charter  1635  1043130
# 38878           73.0        90.0         14  Charter  1635  1043130
# 38880           83.0        75.0         14  Charter  1635  1043130
# 38881           73.0        85.0         14  Charter  1635  1043130
# 38882           88.0        80.0         14  Charter  1635  1043130
# 38883           82.0        84.0         14  Charter  1635  1043130
# 38884           93.0        83.0         14  Charter  1635  1043130
# 38885           99.0        89.0         14  Charter  1635  1043130
# 38886           77.0        87.0         14  Charter  1635  1043130
# 38887           75.0        79.0         14  Charter  1635  1043130
# 38888           72.0        85.0         14  Charter  1635  1043130
# 38890           73.0        80.0         14  Charter  1635  1043130
# 38895           75.0        76.0         14  Charter  1635  1043130
# 38897           85.0        83.0         14  Charter  1635  1043130
# 38898           95.0        80.0         14  Charter  1635  1043130
# 38900           98.0        84.0         14  Charter  1635  1043130
# 38903           93.0        79.0         14  Charter  1635  1043130
# 38904           89.0        71.0         14  Charter  1635  1043130
# 38905           91.0        93.0         14  Charter  1635  1043130
# 38907           93.0        76.0         14  Charter  1635  1043130
# 38908           74.0        81.0         14  Charter  1635  1043130
# 38910           93.0        95.0         14  Charter  1635  1043130
# 38911           91.0        97.0         14  Charter  1635  1043130
# 38912           90.0        74.0         14  Charter  1635  1043130
# 38913           82.0        96.0         14  Charter  1635  1043130
# 38915           94.0        80.0         14  Charter  1635  1043130
# 38917           81.0        71.0         14  Charter  1635  1043130
# 38920           74.0        94.0         14  Charter  1635  1043130
# 38921           96.0        84.0         14  Charter  1635  1043130
# 38922           71.0        71.0         14  Charter  1635  1043130
# 38924           93.0        89.0         14  Charter  1635  1043130
# 38925           70.0        78.0         14  Charter  1635  1043130
# 38926           95.0        93.0         14  Charter  1635  1043130
# 38927           90.0        77.0         14  Charter  1635  1043130
# 38930           90.0        83.0         14  Charter  1635  1043130
# 38931           88.0        87.0         14  Charter  1635  1043130
# 38932           97.0        81.0         14  Charter  1635  1043130
# 38937           90.0        79.0         14  Charter  1635  1043130
# 38938           83.0        96.0         14  Charter  1635  1043130
# 38939           98.0        83.0         14  Charter  1635  1043130
# 38940           80.0        85.0         14  Charter  1635  1043130
# 38943           73.0        75.0         14  Charter  1635  1043130
# 38945           96.0        99.0         14  Charter  1635  1043130
# 38946           74.0        95.0         14  Charter  1635  1043130
# 38947           83.0        90.0         14  Charter  1635  1043130
# 38950           93.0        97.0         14  Charter  1635  1043130
# 38952           94.0        82.0         14  Charter  1635  1043130
# 38954           95.0        77.0         14  Charter  1635  1043130
# 38955           75.0        87.0         14  Charter  1635  1043130
# 38956           81.0        75.0         14  Charter  1635  1043130
# 38957           85.0        70.0         14  Charter  1635  1043130
# 38959           86.0        72.0         14  Charter  1635  1043130
# 38960           87.0        92.0         14  Charter  1635  1043130
# 38961           82.0        70.0         14  Charter  1635  1043130
# 38962           81.0        78.0         14  Charter  1635  1043130
# 38963           80.0        81.0         14  Charter  1635  1043130
# 38965           95.0        79.0         14  Charter  1635  1043130
# 38967           70.0        92.0         14  Charter  1635  1043130
# 38971           97.0        91.0         14  Charter  1635  1043130
# 38973           76.0        98.0         14  Charter  1635  1043130
# 38975           92.0        83.0         14  Charter  1635  1043130
# 38976           71.0        91.0         14  Charter  1635  1043130
# 38978           77.0        92.0         14  Charter  1635  1043130
# 38982           74.0        82.0         14  Charter  1635  1043130
# 38983           73.0        74.0         14  Charter  1635  1043130
# 38984           84.0        92.0         14  Charter  1635  1043130
# 38985           78.0        85.0         14  Charter  1635  1043130
# 38986           70.0        86.0         14  Charter  1635  1043130
# 38987           82.0        77.0         14  Charter  1635  1043130
# 38989           87.0        81.0         14  Charter  1635  1043130
# 38990           99.0        87.0         14  Charter  1635  1043130
# 38991           74.0        99.0         14  Charter  1635  1043130
# 38992           93.0        78.0         14  Charter  1635  1043130
# 38993           91.0        75.0         14  Charter  1635  1043130
# 38995           92.0        80.0         14  Charter  1635  1043130
# 38996           72.0        94.0         14  Charter  1635  1043130
# 38997           93.0        71.0         14  Charter  1635  1043130
# 38998           81.0        97.0         14  Charter  1635  1043130
# 38999           76.0        75.0         14  Charter  1635  1043130
# 39001           98.0        97.0         14  Charter  1635  1043130
# 39002           90.0        77.0         14  Charter  1635  1043130
# 39003           86.0        77.0         14  Charter  1635  1043130
# 39004           74.0        83.0         14  Charter  1635  1043130
# 39005           76.0        86.0         14  Charter  1635  1043130
# 39007           95.0        96.0         14  Charter  1635  1043130
# 39008           84.0        99.0         14  Charter  1635  1043130
# 39009           95.0        73.0         14  Charter  1635  1043130
# 39010           87.0        83.0         14  Charter  1635  1043130
# 39011           93.0        80.0         14  Charter  1635  1043130
# 39012           93.0        83.0         14  Charter  1635  1043130
# 39013           96.0        82.0         14  Charter  1635  1043130
# 39016           87.0        79.0         14  Charter  1635  1043130
# 39017           84.0        87.0         14  Charter  1635  1043130
# 39019           92.0        93.0         14  Charter  1635  1043130
# 39021           87.0        91.0         14  Charter  1635  1043130
# 39022           83.0        98.0         14  Charter  1635  1043130
# 39023           89.0        99.0         14  Charter  1635  1043130
# 39024           88.0        72.0         14  Charter  1635  1043130
# 39025           92.0        87.0         14  Charter  1635  1043130
# 39027           87.0        94.0         14  Charter  1635  1043130
# 39030           83.0        81.0         14  Charter  1635  1043130
# 39031           70.0        90.0         14  Charter  1635  1043130
# 39032           70.0        74.0         14  Charter  1635  1043130
# 39033           99.0        91.0         14  Charter  1635  1043130
# 39034           85.0        82.0         14  Charter  1635  1043130
# 39035           70.0        72.0         14  Charter  1635  1043130
# 39036           76.0        92.0         14  Charter  1635  1043130
# 39037           89.0        86.0         14  Charter  1635  1043130
# 39038           73.0        98.0         14  Charter  1635  1043130
# 39039           98.0        76.0         14  Charter  1635  1043130
# 39040           84.0        88.0         14  Charter  1635  1043130
# 39041           73.0        72.0         14  Charter  1635  1043130
# 39042           73.0        96.0         14  Charter  1635  1043130
# 39043           86.0        92.0         14  Charter  1635  1043130
# 39045           83.0        99.0         14  Charter  1635  1043130
# 39046           71.0        97.0         14  Charter  1635  1043130
# 39047           91.0        74.0         14  Charter  1635  1043130
# 39048           76.0        91.0         14  Charter  1635  1043130
# 39049           98.0        84.0         14  Charter  1635  1043130
# 39050           77.0        70.0         14  Charter  1635  1043130
# 39051           77.0        97.0         14  Charter  1635  1043130
# 39052           74.0        88.0         14  Charter  1635  1043130
# 39053           83.0        85.0         14  Charter  1635  1043130
# 39054           71.0        74.0         14  Charter  1635  1043130
# 39055           87.0        79.0         14  Charter  1635  1043130
# 39056           85.0        72.0         14  Charter  1635  1043130
# 39057           78.0        91.0         14  Charter  1635  1043130
# 39059           95.0        88.0         14  Charter  1635  1043130
# 39062           93.0        70.0         14  Charter  1635  1043130
# 39064           72.0        90.0         14  Charter  1635  1043130
# 39065           85.0        87.0         14  Charter  1635  1043130
# 39066           88.0        89.0         14  Charter  1635  1043130
# 39067           95.0        91.0         14  Charter  1635  1043130
# 39069           90.0        88.0         14  Charter  1635  1043130
# 39071           90.0        97.0         14  Charter  1635  1043130
# 39072           77.0        73.0         14  Charter  1635  1043130
# 39073           71.0        80.0         14  Charter  1635  1043130
# 39077           83.0        81.0         14  Charter  1635  1043130
# 39078           92.0        84.0         14  Charter  1635  1043130
# 39079           88.0        87.0         14  Charter  1635  1043130
# 39081           78.0        76.0         14  Charter  1635  1043130
# 39082           92.0        98.0         14  Charter  1635  1043130
# 39086           74.0        75.0         14  Charter  1635  1043130
# 39088           75.0        83.0         14  Charter  1635  1043130
# 39091           91.0        98.0         14  Charter  1635  1043130
# 39094           96.0        85.0         14  Charter  1635  1043130
# 39095           95.0        82.0         14  Charter  1635  1043130
# 39096           85.0        89.0         14  Charter  1635  1043130
# 39097           87.0        76.0         14  Charter  1635  1043130
# 39098           73.0        94.0         14  Charter  1635  1043130
# 39099           80.0        78.0         14  Charter  1635  1043130
# 39100           79.0        71.0         14  Charter  1635  1043130
# 39104           83.0        95.0         14  Charter  1635  1043130
# 39106           94.0        70.0         14  Charter  1635  1043130
# 39108           85.0        85.0         14  Charter  1635  1043130
# 39110           91.0        90.0         14  Charter  1635  1043130
# 39112           84.0        72.0         14  Charter  1635  1043130
# 39113           78.0        90.0         14  Charter  1635  1043130
# 39114           99.0        77.0         14  Charter  1635  1043130
# 39115           71.0        97.0         14  Charter  1635  1043130
# 39118           82.0        96.0         14  Charter  1635  1043130
# 39119           86.0        94.0         14  Charter  1635  1043130
# 39120           72.0        99.0         14  Charter  1635  1043130
# 39121           94.0        94.0         14  Charter  1635  1043130
# 39125           87.0        99.0         14  Charter  1635  1043130
# 39126           97.0        85.0         14  Charter  1635  1043130
# 39129           81.0        91.0         14  Charter  1635  1043130
# 39130           81.0        76.0         14  Charter  1635  1043130
# 39133           77.0        93.0         14  Charter  1635  1043130
# 39134           83.0        99.0         14  Charter  1635  1043130
# 39136           85.0        97.0         14  Charter  1635  1043130
# 39137           75.0        70.0         14  Charter  1635  1043130
# 39141           86.0        93.0         14  Charter  1635  1043130
# 39142           96.0        83.0         14  Charter  1635  1043130
# 39143           71.0        93.0         14  Charter  1635  1043130
# 39144           77.0        87.0         14  Charter  1635  1043130
# 39145           94.0        74.0         14  Charter  1635  1043130
# 39147           88.0        81.0         14  Charter  1635  1043130
# 39148           89.0        89.0         14  Charter  1635  1043130
# 39149           82.0        93.0         14  Charter  1635  1043130
# 39150           80.0        75.0         14  Charter  1635  1043130
# 39151           84.0        73.0         14  Charter  1635  1043130
# 39154           91.0        71.0         14  Charter  1635  1043130
# 39155           92.0        98.0         14  Charter  1635  1043130
# 39156           79.0        95.0         14  Charter  1635  1043130
# 39158           87.0        90.0         14  Charter  1635  1043130
# 39159           85.0        72.0         14  Charter  1635  1043130
# 39160           89.0        86.0         14  Charter  1635  1043130
# 39161           70.0        84.0         14  Charter  1635  1043130
# 39162           94.0        77.0         14  Charter  1635  1043130
# 39163           90.0        75.0         14  Charter  1635  1043130
# 39165           99.0        90.0         14  Charter  1635  1043130
# 39166           95.0        70.0         14  Charter  1635  1043130
# 39168           99.0        90.0         14  Charter  1635  1043130
# 39169           95.0        75.0         14  Charter  1635  1043130

# %%
# Step 9. Calculate the percentage of 10th-12th grade students passing math from Thomas High School. 
upper_grades_math = school_data_complete_df.loc[(school_data_complete_df["grade"]!= "9th")
                                                   &(school_data_complete_df["school_name"]=="Thomas High School")
                                                &(school_data_complete_df["math_score"] >= 70)].count()['Student ID']

math_passing_percentage = upper_grades_math / total_students * 100
math_passing_percentage
# Out:
# 93.18568994889267

# %%
# Step 10. Calculate the percentage of 10th-12th grade students passing reading from Thomas High School.
upper_grades_reading = school_data_complete_df.loc[(school_data_complete_df["grade"]!= "9th") & (school_data_complete_df["school_name"]=="Thomas High School") & (school_data_complete_df["reading_score"] >= 70)].count()['Student ID']

reading_passing_percentage = upper_grades_reading / total_students * 100
reading_passing_percentage
# Out:
# 97.01873935264055

# %%
# Step 11. Calculate the overall passing percentage of 10th-12th grade from Thomas High School. 
total_grades = total_students_passing["student_name"].count()
overall_passing_percentage =  total_grades / total_students *100
overall_passing_percentage
# Out:
# 90.63032367972743

# %%
# Step 12. Replace the passing math percent for Thomas High School in the per_school_summary_df.
per_school_summary_df.loc[["Thomas High School"],['% Passing Math']]= math_passing_percentage

# %%
# Step 13. Replace the passing reading percentage for Thomas High School in the per_school_summary_df.
per_school_summary_df.loc[["Thomas High School"], ['% Passing Reading']]= reading_passing_percentage

# %%
# Step 14. Replace the overall passing percentage for Thomas High School in the per_school_summary_df.
per_school_summary_df.loc[["Thomas High School"], ['% Overall Passing']]= overall_passing_percentage

# %%
# per_school_summary_df
per_school_summary_df
# Out:
#                       School Type  Total Students Total School Budget  \
# Bailey High School       District            4976       $3,124,928.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Figueroa High School     District            2949       $1,884,411.00
# Ford High School         District            2739       $1,763,916.00
# Griffin High School       Charter            1468         $917,500.00
# Hernandez High School    District            4635       $3,022,020.00
# Holden High School        Charter             427         $248,087.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Pena High School          Charter             962         $585,858.00
# Rodriguez High School    District            3999       $2,547,363.00
# Shelton High School       Charter            1761       $1,056,600.00
# Thomas High School        Charter            1635       $1,043,130.00
# Wilson High School        Charter            2283       $1,319,574.00
# Wright High School        Charter            1800       $1,049,400.00
#
#                       Per Student Budget  Average Math Score  \
# Bailey High School               $628.00           77.048432
# Cabrera High School              $582.00           83.061895
# Figueroa High School             $639.00           76.711767
# Ford High School                 $644.00           77.102592
# Griffin High School              $625.00           83.351499
# Hernandez High School            $652.00           77.289752
# Holden High School               $581.00           83.803279
# Huang High School                $655.00           76.629414
# Johnson High School              $650.00           77.072464
# Pena High School                 $609.00           83.839917
# Rodriguez High School            $637.00           76.842711
# Shelton High School              $600.00           83.359455
# Thomas High School               $638.00           83.350937
# Wilson High School               $578.00           83.274201
# Wright High School               $583.00           83.682222
#
#                        Average Reading Score  % Passing Math  \
# Bailey High School                 81.033963       66.680064
# Cabrera High School                83.975780       94.133477
# Figueroa High School               81.158020       65.988471
# Ford High School                   80.746258       68.309602
# Griffin High School                83.816757       93.392371
# Hernandez High School              80.934412       66.752967
# Holden High School                 83.814988       92.505855
# Huang High School                  81.182722       65.683922
# Johnson High School                80.966394       66.057551
# Pena High School                   84.044699       94.594595
# Rodriguez High School              80.744686       66.366592
# Shelton High School                83.725724       93.867121
# Thomas High School                 83.896082       93.185690
# Wilson High School                 83.989488       93.867718
# Wright High School                 83.955000       93.333333
#
#                        % Passing Reading  % Overall Passing
# Bailey High School             81.933280          54.642283
# Cabrera High School            97.039828          91.334769
# Figueroa High School           80.739234          53.204476
# Ford High School               79.299014          54.289887
# Griffin High School            97.138965          90.599455
# Hernandez High School          80.862999          53.527508
# Holden High School             96.252927          89.227166
# Huang High School              81.316421          53.513884
# Johnson High School            81.222432          53.539172
# Pena High School               95.945946          90.540541
# Rodriguez High School          80.220055          52.988247
# Shelton High School            95.854628          89.892107
# Thomas High School             97.018739          90.630324
# Wilson High School             96.539641          90.582567
# Wright High School             96.611111          90.333333

# %% [markdown]
# ## High and Low Performing Schools

# %%
# Sort and show top five schools.
top_schools = per_school_summary_df.sort_values(["% Overall Passing"], ascending=False)

top_schools.head()
# Out:
#                     School Type  Total Students Total School Budget  \
# Cabrera High School     Charter            1858       $1,081,356.00
# Thomas High School      Charter            1635       $1,043,130.00
# Griffin High School     Charter            1468         $917,500.00
# Wilson High School      Charter            2283       $1,319,574.00
# Pena High School        Charter             962         $585,858.00
#
#                     Per Student Budget  Average Math Score  \
# Cabrera High School            $582.00           83.061895
# Thomas High School             $638.00           83.350937
# Griffin High School            $625.00           83.351499
# Wilson High School             $578.00           83.274201
# Pena High School               $609.00           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# Thomas High School               83.896082       93.185690          97.018739
# Griffin High School              83.816757       93.392371          97.138965
# Wilson High School               83.989488       93.867718          96.539641
# Pena High School                 84.044699       94.594595          95.945946
#
#                      % Overall Passing
# Cabrera High School          91.334769
# Thomas High School           90.630324
# Griffin High School          90.599455
# Wilson High School           90.582567
# Pena High School             90.540541

# %%
# Sort and show bottom five schools.
bottom_schools = per_school_summary_df.sort_values(["% Overall Passing"])
bottom_schools.head()
# Out:
#                       School Type  Total Students Total School Budget  \
# Rodriguez High School    District            3999       $2,547,363.00
# Figueroa High School     District            2949       $1,884,411.00
# Huang High School        District            2917       $1,910,635.00
# Hernandez High School    District            4635       $3,022,020.00
# Johnson High School      District            4761       $3,094,650.00
#
#                       Per Student Budget  Average Math Score  \
# Rodriguez High School            $637.00           76.842711
# Figueroa High School             $639.00           76.711767
# Huang High School                $655.00           76.629414
# Hernandez High School            $652.00           77.289752
# Johnson High School              $650.00           77.072464
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686       66.366592
# Figueroa High School               81.158020       65.988471
# Huang High School                  81.182722       65.683922
# Hernandez High School              80.934412       66.752967
# Johnson High School                80.966394       66.057551
#
#                        % Passing Reading  % Overall Passing
# Rodriguez High School          80.220055          52.988247
# Figueroa High School           80.739234          53.204476
# Huang High School              81.316421          53.513884
# Hernandez High School          80.862999          53.527508
# Johnson High School            81.222432          53.539172

# %% [markdown]
# ## Math and Reading Scores by Grade

# %%
# Create a Series of scores by grade levels using conditionals.
ninth_graders = school_data_complete_df[(school_data_complete_df["grade"] == "9th")]

tenth_graders = school_data_complete_df[(school_data_complete_df["grade"] == "10th")]

eleventh_graders = school_data_complete_df[(school_data_complete_df["grade"] == "11th")]

twelfth_graders = school_data_complete_df[(school_data_complete_df["grade"] == "12th")]

# Group each school Series by the school name for the average math score.
ninth_grade_math_scores = ninth_graders.groupby(["school_name"]).mean()["math_score"]

tenth_grade_math_scores = tenth_graders.groupby(["school_name"]).mean()["math_score"]

eleventh_grade_math_scores = eleventh_graders.groupby(["school_name"]).mean()["math_score"]

twelfth_grade_math_scores = twelfth_graders.groupby(["school_name"]).mean()["math_score"]


# Group each school Series by the school name for the average reading score.
ninth_grade_reading_scores = ninth_graders.groupby(["school_name"]).mean()["reading_score"]

tenth_grade_reading_scores = tenth_graders.groupby(["school_name"]).mean()["reading_score"]

eleventh_grade_reading_scores = eleventh_graders.groupby(["school_name"]).mean()["reading_score"]

twelfth_grade_reading_scores = twelfth_graders.groupby(["school_name"]).mean()["reading_score"]

# %%
# Combine each Series for average math scores by school into single data frame.
math_scores_by_grade = pd.DataFrame({
               "9th": ninth_grade_math_scores,
               "10th": tenth_grade_math_scores,
               "11th": eleventh_grade_math_scores,
               "12th": twelfth_grade_math_scores})

math_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School           NaN  83.087886  83.498795  83.497041
# Wilson High School     83.085578  83.724422  83.195326  83.035794
# Wright High School     83.264706  84.010288  83.836782  83.644986

# %%
# Combine each Series for average reading scores by school into single data frame.
reading_scores_by_grade = pd.DataFrame({
              "9th": ninth_grade_reading_scores,
              "10th": tenth_grade_reading_scores,
              "11th": eleventh_grade_reading_scores,
              "12th": twelfth_grade_reading_scores})

reading_scores_by_grade.head()
# Out:
#                             9th       10th       11th       12th
# school_name
# Bailey High School    81.303155  80.907183  80.945643  80.912451
# Cabrera High School   83.676136  84.253219  83.788382  84.287958
# Figueroa High School  81.198598  81.408912  80.640339  81.384863
# Ford High School      80.632653  81.262712  80.403642  80.662338
# Griffin High School   83.369193  83.706897  84.288089  84.013699

# %%
# Format each grade column.
math_scores_by_grade["9th"] = math_scores_by_grade["9th"].map("{:.1f}".format)

math_scores_by_grade["10th"] = math_scores_by_grade["10th"].map("{:.1f}".format)

math_scores_by_grade["11th"] = math_scores_by_grade["11th"].map("{:.1f}".format)

math_scores_by_grade["12th"] = math_scores_by_grade["12th"].map("{:.1f}".format)

reading_scores_by_grade["9th"] = reading_scores_by_grade["9th"].map("{:,.1f}".format)

reading_scores_by_grade["10th"] = reading_scores_by_grade["10th"].map("{:,.1f}".format)

reading_scores_by_grade["11th"] = reading_scores_by_grade["11th"].map("{:,.1f}".format)

reading_scores_by_grade["12th"] = reading_scores_by_grade["12th"].map("{:,.1f}".format)

# %%
# Remove the index.
math_scores_by_grade.index.name = None

# Display the data frame
math_scores_by_grade.head()
# Out:
#                        9th  10th  11th  12th
# Bailey High School    77.1  77.0  77.5  76.5
# Cabrera High School   83.1  83.2  82.8  83.3
# Figueroa High School  76.4  76.5  76.9  77.2
# Ford High School      77.4  77.7  76.9  76.2
# Griffin High School   82.0  84.2  83.8  83.4

# %%
## Remove the index.
reading_scores_by_grade.index.name = None

# Display the data frame
reading_scores_by_grade.head()
# Out:
#                        9th  10th  11th  12th
# Bailey High School    81.3  80.9  80.9  80.9
# Cabrera High School   83.7  84.3  83.8  84.3
# Figueroa High School  81.2  81.4  80.6  81.4
# Ford High School      80.6  81.3  80.4  80.7
# Griffin High School   83.4  83.7  84.3  84.0

# %% [markdown]
# ## Scores by School Spending

# %%
# Establish the spending bins and group names.
spending_bins = [0, 585, 630, 645, 675]

# Categorize spending based on the bins.
group_names = ["<$584", "$585-629", "$630-644", "$645-675"]
per_school_summary_df.head()
# Out:
#                      School Type  Total Students Total School Budget  \
# Bailey High School      District            4976       $3,124,928.00
# Cabrera High School      Charter            1858       $1,081,356.00
# Figueroa High School    District            2949       $1,884,411.00
# Ford High School        District            2739       $1,763,916.00
# Griffin High School      Charter            1468         $917,500.00
#
#                      Per Student Budget  Average Math Score  \
# Bailey High School              $628.00           77.048432
# Cabrera High School             $582.00           83.061895
# Figueroa High School            $639.00           76.711767
# Ford High School                $644.00           77.102592
# Griffin High School             $625.00           83.351499
#
#                       Average Reading Score  % Passing Math  \
# Bailey High School                81.033963       66.680064
# Cabrera High School               83.975780       94.133477
# Figueroa High School              81.158020       65.988471
# Ford High School                  80.746258       68.309602
# Griffin High School               83.816757       93.392371
#
#                       % Passing Reading  % Overall Passing
# Bailey High School            81.933280          54.642283
# Cabrera High School           97.039828          91.334769
# Figueroa High School          80.739234          53.204476
# Ford High School              79.299014          54.289887
# Griffin High School           97.138965          90.599455

# %%
# Calculate averages for the desired columns. 
spending_math_scores = per_school_summary_df.groupby(["Per Student Budget"]).mean()["Average Math Score"]

spending_reading_scores = per_school_summary_df.groupby(["Per Student Budget"]).mean()["Average Reading Score"]

spending_passing_math = per_school_summary_df.groupby(["Per Student Budget"]).mean()["% Passing Math"]

spending_passing_reading = per_school_summary_df.groupby(["Per Student Budget"]).mean()["% Passing Reading"]

overall_passing_spending = per_school_summary_df.groupby(["Per Student Budget"]).mean()["% Overall Passing"]

# %%
# Create the DataFrame
spending_summary_df = pd.DataFrame({
          "Average Math Score" : spending_math_scores,
          "Average Reading Score": spending_reading_scores,
          "% Passing Math": spending_passing_math,
          "% Passing Reading": spending_passing_reading,
          "% Overall Passing": overall_passing_spending})

spending_summary_df
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# Per Student Budget
# $578.00                      83.274201              83.989488       93.867718
# $581.00                      83.803279              83.814988       92.505855
# $582.00                      83.061895              83.975780       94.133477
# $583.00                      83.682222              83.955000       93.333333
# $600.00                      83.359455              83.725724       93.867121
# $609.00                      83.839917              84.044699       94.594595
# $625.00                      83.351499              83.816757       93.392371
# $628.00                      77.048432              81.033963       66.680064
# $637.00                      76.842711              80.744686       66.366592
# $638.00                      83.350937              83.896082       93.185690
# $639.00                      76.711767              81.158020       65.988471
# $644.00                      77.102592              80.746258       68.309602
# $650.00                      77.072464              80.966394       66.057551
# $652.00                      77.289752              80.934412       66.752967
# $655.00                      76.629414              81.182722       65.683922
#
#                     % Passing Reading  % Overall Passing
# Per Student Budget
# $578.00                     96.539641          90.582567
# $581.00                     96.252927          89.227166
# $582.00                     97.039828          91.334769
# $583.00                     96.611111          90.333333
# $600.00                     95.854628          89.892107
# $609.00                     95.945946          90.540541
# $625.00                     97.138965          90.599455
# $628.00                     81.933280          54.642283
# $637.00                     80.220055          52.988247
# $638.00                     97.018739          90.630324
# $639.00                     80.739234          53.204476
# $644.00                     79.299014          54.289887
# $650.00                     81.222432          53.539172
# $652.00                     80.862999          53.527508
# $655.00                     81.316421          53.513884

# %%
# Format the DataFrame 
spending_summary_df["Average Math Score"] = spending_summary_df["Average Math Score"].map("{:.1f}".format)

spending_summary_df["Average Reading Score"] = spending_summary_df["Average Reading Score"].map("{:.1f}".format)

spending_summary_df["% Passing Math"] = spending_summary_df["% Passing Math"].map("{:.0f}".format)

spending_summary_df["% Passing Reading"] = spending_summary_df["% Passing Reading"].map("{:.0f}".format)

spending_summary_df["% Overall Passing"] = spending_summary_df["% Overall Passing"].map("{:.0f}".format)

spending_summary_df
# Out:
#                    Average Math Score Average Reading Score % Passing Math  \
# Per Student Budget
# $578.00                          83.3                  84.0             94
# $581.00                          83.8                  83.8             93
# $582.00                          83.1                  84.0             94
# $583.00                          83.7                  84.0             93
# $600.00                          83.4                  83.7             94
# $609.00                          83.8                  84.0             95
# $625.00                          83.4                  83.8             93
# $628.00                          77.0                  81.0             67
# $637.00                          76.8                  80.7             66
# $638.00                          83.4                  83.9             93
# $639.00                          76.7                  81.2             66
# $644.00                          77.1                  80.7             68
# $650.00                          77.1                  81.0             66
# $652.00                          77.3                  80.9             67
# $655.00                          76.6                  81.2             66
#
#                    % Passing Reading % Overall Passing
# Per Student Budget
# $578.00                           97                91
# $581.00                           96                89
# $582.00                           97                91
# $583.00                           97                90
# $600.00                           96                90
# $609.00                           96                91
# $625.00                           97                91
# $628.00                           82                55
# $637.00                           80                53
# $638.00                           97                91
# $639.00                           81                53
# $644.00                           79                54
# $650.00                           81                54
# $652.00                           81                54
# $655.00                           81                54

# %% [markdown]
# ## Scores by School Size

# %%
# Establish the bins.
size_bins = [0, 1000, 2000, 5000]
# Categorize spending based on the bins.
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]
per_school_summary_df["School Size"] = pd.cut(per_school_summary_df["Total Students"], size_bins, labels=group_names)

# %%
# Calculate averages for the desired columns. 
size_math_scores = per_school_summary_df.groupby(["School Size"]).mean()["Average Math Score"]

size_reading_scores = per_school_summary_df.groupby(["School Size"]).mean()["Average Reading Score"]

size_passing_math = per_school_summary_df.groupby(["School Size"]).mean()["% Passing Math"]

size_passing_reading = per_school_summary_df.groupby(["School Size"]).mean()["% Passing Reading"]

size_overall_passing = per_school_summary_df.groupby(["School Size"]).mean()["% Overall Passing"]

# %%
# Assemble into DataFrame. 
size_summary_df = pd.DataFrame({
          "Average Math Score" : size_math_scores,
          "Average Reading Score": size_reading_scores,
          "% Passing Math": size_passing_math,
          "% Passing Reading": size_passing_reading,
          "% Overall Passing": size_overall_passing})
size_summary_df
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.361201              83.873869       93.582398
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading  % Overall Passing
# School Size
# Small (<1000)               96.099437          89.883853
# Medium (1000-2000)          96.732654          90.557997
# Large (2000-5000)           82.766634          58.286003

# %%
# Format the DataFrame  
size_summary_df["Average Math Score"] = size_summary_df["Average Math Score"].map("{:.1f}".format)

size_summary_df["Average Reading Score"] = size_summary_df["Average Reading Score"].map("{:.1f}".format)

size_summary_df["% Passing Math"] = size_summary_df["% Passing Math"].map("{:.0f}".format)

size_summary_df["% Passing Reading"] = size_summary_df["% Passing Reading"].map("{:.0f}".format)

size_summary_df["% Overall Passing"] = size_summary_df["% Overall Passing"].map("{:.0f}".format)

size_summary_df
# Out:
#                    Average Math Score Average Reading Score % Passing Math  \
# School Size
# Small (<1000)                    83.8                  83.9             94
# Medium (1000-2000)               83.4                  83.9             94
# Large (2000-5000)                77.7                  81.3             70
#
#                    % Passing Reading % Overall Passing
# School Size
# Small (<1000)                     96                90
# Medium (1000-2000)                97                91
# Large (2000-5000)                 83                58

# %% [markdown]
# ## Scores by School Type

# %%
# Calculate averages for the desired columns. 
type_math_scores = per_school_summary_df.groupby(["School Type"]).mean()["Average Math Score"]

type_reading_scores = per_school_summary_df.groupby(["School Type"]).mean()["Average Reading Score"]

type_passing_math = per_school_summary_df.groupby(["School Type"]).mean()["% Passing Math"]

type_passing_reading = per_school_summary_df.groupby(["School Type"]).mean()["% Passing Reading"]

type_overall_passing = per_school_summary_df.groupby(["School Type"]).mean()["% Overall Passing"]

# %%
# Assemble into DataFrame. 
type_summary_df = pd.DataFrame({
          "Average Math Score" : type_math_scores,
          "Average Reading Score": type_reading_scores,
          "% Passing Math": type_passing_math,
          "% Passing Reading": type_passing_reading,
          "% Overall Passing": type_overall_passing})

type_summary_df
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.465425              83.902315       93.610020
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.550223          90.392533
# District             80.799062          53.672208

# %%
# # Format the DataFrame 
type_summary_df["Average Math Score"] = type_summary_df["Average Math Score"].map("{:.1f}".format)

type_summary_df["Average Reading Score"] = type_summary_df["Average Reading Score"].map("{:.1f}".format)

type_summary_df["% Passing Math"] = type_summary_df["% Passing Math"].map("{:.0f}".format)

type_summary_df["% Passing Reading"] = type_summary_df["% Passing Reading"].map("{:.0f}".format)

type_summary_df["% Overall Passing"] = type_summary_df["% Overall Passing"].map("{:.0f}".format)

type_summary_df
# Out:
#             Average Math Score Average Reading Score % Passing Math  \
# School Type
# Charter                   83.5                  83.9             94
# District                  77.0                  81.0             67
#
#             % Passing Reading % Overall Passing
# School Type
# Charter                    97                90
# District                   81                54
